# %%
import wave, struct, math, random
import numpy as np
notes = {
    "C3":262,
    "C#3":277,
    "D3":294,
    "D#3":311,
    "F3":330,
    "F#3":349,
    "G3":370,
    "G#3":415,
    "A4":440,
    "A#4":466,
    "B4":494,
    "C4":523,
    "C#4":554,
    "D4":587,
    "D#4":622,
    "E4":659,
    "F4":698,
    "F#4":740,
    "G4":784,
    "G#4":831,
    "A5":880,
    "A#5":932,
    "B5":988,
    "C5":1047
}

# %%
sampleRate = 44100 # hertz
obj = wave.open('music.wav','w')
obj.setnchannels(1) # mono
obj.setsampwidth(2)
obj.setframerate(sampleRate)

def writeWav(frequency,obj,duration):
    sampleRate = 44100 # hertz
    duration = 1.0 # seconds

    time = np.arange(0,2,1/sampleRate)
    sinewave=32767*np.sin(2*np.pi*frequency*time)
    for i in range(int(sampleRate*duration)):
       value = int(sinewave[i])
       data = struct.pack('<h', value)
       obj.writeframesraw( data )

    
    
#This must all be done in the same cell, there is a strange error that comes up when running the writeWav() function outside
#of the cell that it is defined in.
#TODO: use writeWav() to make a song
obj.close()

# %%
from IPython.display import Audio as IPAudio
IPAudio(filename) #replace with your filename
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-26-1dca6bacc5ed> in <module>()
#       3 pAudio = base.audio
#       4 pAudio.set_volume(20)
# ----> 5 pAudio.load("test4.wav")
#       6 pAudio.play()
#
# /usr/local/lib/python3.6/dist-packages/pynq/lib/audio.py in load(self, file)
#     592             self.sample_len = wav_file.getnframes()
#     593         byte_format = ('%ds' % 3) * self.sample_len * 2
# --> 594         samples_4byte = b'\x00'.join(struct.unpack(byte_format, samples_3byte))
#     595         samples_4byte += b'\x00'
#     596         self.buffer = numpy.fromstring(samples_4byte, dtype='<u4')
#
# error: unpack requires a buffer of 529200 bytes
